# %%
import numpy as np

# %%
vetor = [ int(input(f'digite o {i + 1} número: ')) for i in range(5)]
print(vetor)
print(max(vetor))
print(min(vetor))
print(sum(vetor) / len(vetor))
# Out:
# digite o 1 número: 1
# digite o 2 número: 2
# digite o 3 número: 3
# digite o 4 número: 4
# digite o 5 número: 5
# [1, 2, 3, 4, 5]
# 5
# 1
# 3.0
